# %%
#Q1

balance = int(input("enter your balance: "))
pin = int(input("enter your pin: "))
withdrawal_amt = int(input("enter withdrawal amount: "))
if pin == 1234:
    if withdrawal_amt % 100 == 0:
        if balance >= withdrawal_amt:
            print("Successful withdrawal!")
        else:
            print("Insufficient balance!")
    else:
        print("Enter valid amount!")
else:
    print("Incorrect PIN!")

# %%
#Q2

year = int(input("enter year: "))
month = input("enter month: ")
month = month.lower()
month_31 = ["jan","mar","may","july","aug","oct","dec"]
month_30 = ["apr","june","sep","nov"]

if month == "feb":
    if year%4 ==0 and year%100==0:
        if year%400==0:
              print("29 days in feb in",year)
        if year%400!=0:
              print("28 days in feb in",year)
    elif year%4 ==0:
            print("29 days in feb in",year)              
    else:
        print("28 days in feb in",year)
elif month in month_31:
            print("31 days in",month,"in",year)
elif month in month_30:
    print("30 days in",month,"in",year)
else:
    print("invalid year!")

# %%
#Q3

nums= input("enter 2 numbers: ")
x,y = (nums.split())
x=int(x)
y=int(y)
print("two numbers are",x,"and",y)
print(f'''1.Addition: {x+y}
2.Subtraction: {x-y}
3.Multiplication: {x*y}''')
if y!=0:
    print(f'''4.Division: {x/y}
5.Modulus: {x%y}''')
else:
    print("Division and modulus cannot be performed because the second number is 0.")

# %%
#Q4

list = [i**2 for i in range(1,21)]
print("squares:",list)
even_sq = [x for x in list if x%2==0]
print("even squares:",even_sq)

# %%
#Q5

stu_marks = {"a":70, "b":60, "c":90, "d":100, "e":85 }
for i in stu_marks:
    print(i)
print("a:",stu_marks["a"])
x = max(stu_marks.values())
for x,y in stu_marks.items():
    if y==max(stu_marks.values()):
        print(x,"got highest marks")
    else:
        pass
stu_marks["f"] = 75
print(stu_marks)

# %%
#Q6

student = {"name":"anupam","age":22,"course":"B.tech."}
set = {1,2,3,4,5}
string1 = input("enter a string: ")
strtoint = int(string1)
print(student)
print(set)
print(string1)
print(strtoint)
